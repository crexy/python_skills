# %%
import pandas as pd
import FinanceDataReader as fdr
import matplotlib.pyplot as plt

# %%
# 종목 리스트
df_spx = fdr.StockListing('S&P500')

print(len(df_spx))
df_spx.head()
# Out:
# 503
#   Symbol                 Name                  Sector  \
# 0    MMM                   3M             Industrials
# 1    AOS          A. O. Smith             Industrials
# 2    ABT               Abbott             Health Care
# 3    ACN            Accenture  Information Technology
# 4   ATVI  Activision Blizzard  Communication Services
#
#                          Industry
# 0        Industrial Conglomerates
# 1               Building Products
# 2           Health Care Equipment
# 3  IT Consulting & Other Services
# 4  Interactive Home Entertainment

# %%
# 종목 OHLCV 데이터 로드
df = fdr.DataReader('US500', start='2022-01-01')
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059  4796.560059
# 2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039  4793.540039
# 2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078  4700.580078
# 2022-01-06  4693.390137  4725.009766  4671.259766  4696.049805  4696.049805
# 2022-01-07  4697.660156  4707.950195  4662.740234  4677.029785  4677.029785
#
#                 Volume
# Date
# 2022-01-03  3831020000
# 2022-01-04  4683170000
# 2022-01-05  4887960000
# 2022-01-06  4295280000
# 2022-01-07  4181510000

# %%
df["Adj Close"].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.to_csv("./data/SP500_20220101-.csv")

# %%
df[:3]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059  4796.560059
# 2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039  4793.540039
# 2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078  4700.580078
#
#                 Volume
# Date
# 2022-01-03  3831020000
# 2022-01-04  4683170000
# 2022-01-05  4887960000

# %%
# 종목 기간 필터링
df['2022-01-03':'2022-01-30']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059  4796.560059
# 2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039  4793.540039
# 2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078  4700.580078
# 2022-01-06  4693.390137  4725.009766  4671.259766  4696.049805  4696.049805
# 2022-01-07  4697.660156  4707.950195  4662.740234  4677.029785  4677.029785
# 2022-01-10  4655.339844  4673.020020  4582.240234  4670.290039  4670.290039
# 2022-01-11  4669.140137  4714.129883  4638.270020  4713.069824  4713.069824
# 2022-01-12  4728.589844  4748.830078  4706.709961  4726.350098  4726.350098
# 2022-01-13  4733.560059  4744.129883  4650.290039  4659.029785  4659.029785
# 2022-01-14  4637.990234  4665.129883  4614.750000  4662.850098  4662.850098
# 2022-01-18  4632.240234  4632.240234  4568.700195  4577.109863  4577.109863
# ...

# %%
# 인덱스 미지정 데이터로드
df = pd.read_csv("./data/SP500_20220101-.csv")
print(df.head())
print(type(df.index))
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059
# 1  2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039
# 2  2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078
# 3  2022-01-06  4693.390137  4725.009766  4671.259766  4696.049805
# 4  2022-01-07  4697.660156  4707.950195  4662.740234  4677.029785
#
#      Adj Close      Volume
# 0  4796.560059  3831020000
# 1  4793.540039  4683170000
# 2  4700.580078  4887960000
# 3  4696.049805  4295280000
# 4  4677.029785  4181510000
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
# 날짜 컬럼을 인덱스로 지정 후 데이터 로드
df = pd.read_csv("./data/SP500_20220101-.csv", index_col="Date", parse_dates=['Date'])
print(type(df.index))
df.head()
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059  4796.560059
# 2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039  4793.540039
# 2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078  4700.580078
# 2022-01-06  4693.390137  4725.009766  4671.259766  4696.049805  4696.049805
# 2022-01-07  4697.660156  4707.950195  4662.740234  4677.029785  4677.029785
#
#                 Volume
# Date
# 2022-01-03  3831020000
# 2022-01-04  4683170000
# 2022-01-05  4887960000
# 2022-01-06  4295280000
# 2022-01-07  4181510000

# %%
# 날짜 인덱스, 월 단위로 데이터 필터링
df.loc['2022-3']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-03-01  4363.140137  4378.450195  4279.540039  4306.259766  4306.259766
# 2022-03-02  4322.560059  4401.479980  4322.560059  4386.540039  4386.540039
# 2022-03-03  4401.310059  4416.779785  4345.560059  4363.490234  4363.490234
# 2022-03-04  4342.120117  4342.120117  4284.979980  4328.870117  4328.870117
# 2022-03-07  4327.009766  4327.009766  4199.850098  4201.089844  4201.089844
# 2022-03-08  4202.660156  4276.939941  4157.870117  4170.700195  4170.700195
# 2022-03-09  4223.100098  4299.399902  4223.100098  4277.879883  4277.879883
# 2022-03-10  4252.549805  4268.279785  4209.799805  4259.520020  4259.520020
# 2022-03-11  4279.500000  4291.009766  4200.490234  4204.310059  4204.310059
# 2022-03-14  4202.750000  4247.569824  4161.720215  4173.109863  4173.109863
# 2022-03-15  4188.819824  4271.049805  4187.899902  4262.450195  4262.450195
# ...

# %%
# 한국 종목 로드
df_krx = fdr.StockListing("KRX")
print(len(df_krx))
df_krx.head()
# Out:
# 2690
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        60400          2     -300
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       473500          1     9500
# 2  000660  KR7000660001    SK하이닉스  KOSPI        86500          1      500
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       799000          2   -13000
# 4  005935  KR7005931001     삼성전자우  KOSPI        55000          1      200
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0        -0.49   60200   61100   59900  14859797  898812198128
# 1         2.05  473500  484000  467000    608987  290488630500
# 2         0.58   85500   87200   85000   3105311  268141293128
# 3        -1.60  816000  819000  799000     65628   52739681000
# 4         0.36   54800   55000   54400    961905   52672889220
#
#             Marcap      Stocks MarketId
# 0  360574866020000  5969782550      STK
# 1  110799000000000   234000000      STK
# ...

# %%
df = fdr.DataReader("000660", "2020")
df.head(10)
df.Close.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.to_csv("./data/KRX_000660_2020_.csv")
